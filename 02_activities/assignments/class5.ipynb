# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
from io import BytesIO
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.subplots(figsize=(10,3))


tipgraph = sns.lineplot(data = tips,
                        x =  'total_bill',
                        y = 'tip',
                        color = 'hotpink',
                        linestyle = '--',
                        linewidth = 3,
                        marker = 'o',
                        markerfacecolor = 'indigo')

tipgraph.set(title = 'Tips vs. Total Bill',
             xlabel = 'total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10,3))

tipgraph = sns.lineplot(data = tips,
                        x =  'total_bill',
                        y = 'tip',
                        style = 'time',
                        hue = 'day',
                        palette = ['purple', 'hotpink', 'deepskyblue', 'yellowgreen'])
                        

tipgraph.set(title = 'Tips vs. Total Bill',
             xlabel = 'total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
daysplot = sns.relplot(data = tips,
                       x = 'total_bill',
                       y = 'tip',
                       hue = 'sex',
                       col = 'day',
                       kind = 'scatter',
                       col_wrap = 2)
daysplot

# %%
import plotly.graph_objects as go

x1 = np.array(["Lufy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110,180,240,90,220])

# %%
graph = go.Figure()

graph.add_trace(go.Bar(x=x1, y=y1))

graph.update_layout(title = "Pirate Scores",
                    xaxis_title = "Pirates",
                    yaxis_title = "Score")

# %%
graph = go.Figure()

graph.add_trace(go.Scatter(
                x=x1, 
                y=y1,
                mode = 'markers',
                marker = dict(
                    size = 15,
                    color = 'hotpink',
                    opacity = 1,
                    line = dict(width = 5,
                                color = 'purple')
                )))

graph.update_layout(title = "Interactive Pirate Plot",
                    xaxis_title = "Pirates",
                    yaxis_title = "Score",
                    width = 500,
                    height = 500)

# %%
pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.9.1)
# Requirement already satisfied: numpy in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.26.4)
# Requirement already satisfied: scipy in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (6.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from wordcloud) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (6.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
                on_bad_lines = 'skip')

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

A =  set(['apple', 'banana', 'watermelon'])
B =  set (['pumpkin', 'blueberry', 'apple', 'key lime'])

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

A =  set(['apple', 'banana', 'watermelon'])
B =  set (['pumpkin', 'blueberry', 'apple', 'key lime'])

diagram = venn2([A,B],
              set_labels = ('Fruits', 'Pies'),
              set_colors = ('blue', 'red'),
              alpha = 0.5)

diagram.get_label_by_id("10").set_text("\n".join(A-B))
